# %%
import sqlalchemy as db
import pandas as pd

# %%
engine = db.create_engine('sqlite:///../data/raw/data.db')


with engine.connect() as conn:
    tray = pd.read_sql('SELECT * FROM Macro', con=conn)

tray.tail()
# Out:
#                              date         serie  value
# 99658  2026-03-27 00:00:00.000000         T5YIE   2.56
# 99659  2026-03-27 00:00:00.000000        T10YIE   2.31
# 99660  2026-03-27 00:00:00.000000  BAMLH0A0HYM2   3.42
# 99661  2026-03-27 00:00:00.000000    BAMLC0A0CM   0.91
# 99662  2026-03-27 00:00:00.000000          SOFR   3.63
